# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales_df = pd.read_csv("D:/STUDIES/Projects/Data Analysis/Brazilian E-commerce Data Analysis/Data/Processed/sales_data_merged.csv")

# %%
sales_df.isnull().sum()
# Out:
# order_id                           0
# customer_id                        0
# order_status                       0
# order_purchase_timestamp           0
# order_approved_at                 12
# order_delivered_carrier_date     778
# order_delivered_customer_date      0
# order_estimated_delivery_date      0
# date_ordinal                       0
# shipping_time                      0
# shipping_duration                  0
# estimated_duration                 0
# delivered_time                     0
# estimate_time                      0
# diff_days                          0
# weekly                             0
# product_id                         0
# qty                                0
# seller_id                          0
# shipping_limit_date                0
# price                              0
# freight_value                      0
# product_category_name              0
# product_name_length                0
# product_description_length         0
# ...

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85035 entries, 0 to 85034
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       85035 non-null  object
#  1   customer_id                    85035 non-null  object
#  2   order_status                   85035 non-null  object
#  3   order_purchase_timestamp       85035 non-null  object
#  4   order_approved_at              85023 non-null  object
#  5   order_delivered_carrier_date   84257 non-null  object
#  6   order_delivered_customer_date  85035 non-null  object
#  7   order_estimated_delivery_date  85035 non-null  object
#  8   date_ordinal                   85035 non-null  int64
#  9   shipping_time                  85035 non-null  object
#  10  shipping_duration              85035 non-null  object
#  11  estimated_duration             85035 non-null  object
# ...

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='weekly', y='diff_days', data=sales_df, color="coral", linewidth=5,
            markers=True,dashes=False, estimator='mean')

plt.xlabel("Weeks", size=14)
plt.ylabel("Difference Days", size=14)
plt.title("Average Difference Days per Week",size=15, weight='bold')
plt.show()

# %%
# Check the order delivery that is not delivered yet
sales_df[sales_df["order_delivered_carrier_date"].isnull()]
# Out:
#                                order_id                       customer_id  \
# 1      71303d7e93b399f5bcd537d124c0bcfa  b106b360fe2ef8849fbbd056f777b4d5
# 40     711b9be9c346d9ecdb9d38a5e1e7e39b  81e4aed5ab4253757305267b80712689
# 42     966f96af9d189dc428ff04ebbca821b8  90e1931af4fb878dbe45c79e6e458015
# 49     dd359d3c294458c6d642b2eea9212bf5  5c58d1ea5a893380ecdd96dd6dfd5ec5
# 63     bfd31c6f76ff82a41e7beb05565aec4d  6c65055adfbc0007dbb4c5a22ea5ba8c
# ...                                 ...                               ...
# 82679  d67b79fea59821fda4d363d337a56c3a  f2bea5055b5b15b6b57d07408a1c454a
# 82997  00310b0c75bb13015ec4d82d341865a4  0dad07848c618cc5a4679a1bfe1db8d2
# 83243  a9491b6c990bc3b79967c5f058e46d8f  ef1615358c72dae1c068aedc495a13f3
# 83525  acfa87544c19d596707d25cf2f7dab61  d5feeb223000c4c6dfdb7219b681e1d4
# 84769  ded456690bcb2ffd4def86541479037f  e72188520e7450d41369c84fed0a4b68
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...
